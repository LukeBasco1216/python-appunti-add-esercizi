# %% [markdown]
# ##Merging
#
# Come è possibile unire le informazioni provenienti da dataframe diversi?
#
# https://pandas.pydata.org/pandas-docs/stable/user_guide/merging.html
#
# https://datascienceparichay.com/article/understanding-joins-in-pandas/
#
# Vediamo un esempio con il database della polizia locale che memorizza le informazioni sui proprietari delle auto, le tipologie di infrazioni al codice della strada e le multe che sono state date dai vigili agli automobilisti indisciplinati.

# %%
import pymongo
client = pymongo.MongoClient(
    "mongodb://webUser:xxx123xxx@cluster0-shard-00-00.algwo.mongodb.net:27017,cluster0-shard-00-01.algwo.mongodb.net:27017,cluster0-shard-00-02.algwo.mongodb.net:27017/myFirstDatabase?ssl=true&replicaSet=atlas-am4cb3-shard-0&authSource=admin&retryWrites=true&w=majority")
db = client.polizia_locale # nome del database
multe = db.multe
multe1 = db.multe1
prop = db.proprietari_auto
tipo_infraz = db.tipologia_infrazioni

# %%
import pandas as pd

# %%
df_multe = pd.DataFrame(multe.find())
df_multe1 = pd.DataFrame(multe1.find())
df_prop = pd.DataFrame(prop.find())
df_tipo_infraz = pd.DataFrame(tipo_infraz.find())

# %%
df_multe
# Out:
#                         _id    targa                data  codice_infrazione
# 0  61a3c339002f6ba194601ee7  BM665RE 2021-10-10 22:00:00                  1
# 1  61a3c339002f6ba194601eeb  DS456AS 2021-10-17 22:00:00                  2
# 2  61a3c339002f6ba194601eea  DS456AS 2021-10-18 22:00:00                  3
# 3  61a3c339002f6ba194601ee9  BM665RE 2021-10-18 22:00:00                  1
# 4  61a3c339002f6ba194601ee8  DS456AS 2021-10-10 22:00:00                  2

# %%
df_multe1
# Out:
#                         _id    targa                data  codice_infrazione
# 0  61a3c36c002f6ba194601ef1  DS456AS 2021-11-16 23:00:00                  3
# 1  61a3c36c002f6ba194601ef2  DS456AS 2021-11-12 23:00:00                  5
# 2  61a3c36c002f6ba194601eef  DS456AS 2021-11-11 23:00:00                  2
# 3  61a3c36c002f6ba194601ef0  BM665RE 2021-11-16 23:00:00                  4
# 4  61a3c36c002f6ba194601ef3  XX000YY 2021-11-18 23:00:00                  5
# 5  61a3c36c002f6ba194601eee  BM665RE 2021-11-27 23:00:00                  5

# %%
df_prop
# Out:
#                         _id     nome  cognome    targa
# 0  61a3bf26002f6ba194601eba    carlo    verdi  DD876CA
# 1  61a3bf26002f6ba194601eb9    carlo    verdi  DS456AS
# 2  61a3bf26002f6ba194601eb8    mario    rossi  BM665RE
# 3  61a3bf26002f6ba194601ebb  stefano  bianchi  AS765ZA

# %%
df_tipo_infraz
# Out:
#                         _id  ...                                               note
# 0  61a49d205a4cb744e63c8d38  ...                  sospensione patente da 2 a 6 mesi
# 1  61a49d205a4cb744e63c8d36  ...                   tra 10 e 40 km/h oltre il limite
# 2  61a49d205a4cb744e63c8d35  ...                     fino a 10 km/h oltre il limite
# 3  61a49d205a4cb744e63c8d39  ...                    eventuale arresto da 1 a 8 mesi
# 4  61a49d205a4cb744e63c8d37  ...  sospensione patente da 1 a 3 mesi se recidiva ...
# 5  61a49d205a4cb744e63c8d3a  ...           eventuale arresto da sei mesi ad un anno
#
# [6 rows x 6 columns]

# %% [markdown]
# Vediamo come è possibile unire due dataframe che presentano la stessa struttura:

# %%
df_multe_complessivo = df_multe.append(df_multe1)
df_multe_complessivo
# Out:
#                         _id    targa                data  codice_infrazione
# 0  61a3c339002f6ba194601ee7  BM665RE 2021-10-10 22:00:00                  1
# 1  61a3c339002f6ba194601eeb  DS456AS 2021-10-17 22:00:00                  2
# 2  61a3c339002f6ba194601eea  DS456AS 2021-10-18 22:00:00                  3
# 3  61a3c339002f6ba194601ee9  BM665RE 2021-10-18 22:00:00                  1
# 4  61a3c339002f6ba194601ee8  DS456AS 2021-10-10 22:00:00                  2
# 0  61a3c36c002f6ba194601ef1  DS456AS 2021-11-16 23:00:00                  3
# 1  61a3c36c002f6ba194601ef2  DS456AS 2021-11-12 23:00:00                  5
# 2  61a3c36c002f6ba194601eef  DS456AS 2021-11-11 23:00:00                  2
# 3  61a3c36c002f6ba194601ef0  BM665RE 2021-11-16 23:00:00                  4
# 4  61a3c36c002f6ba194601ef3  XX000YY 2021-11-18 23:00:00                  5
# 5  61a3c36c002f6ba194601eee  BM665RE 2021-11-27 23:00:00                  5

# %%
df_multe_complessivo = df_multe.append(df_multe1).reset_index()
df_multe_complessivo
# Out:
#     index                       _id  ...                data codice_infrazione
# 0       0  61a3c339002f6ba194601ee7  ... 2021-10-10 22:00:00                 1
# 1       1  61a3c339002f6ba194601eeb  ... 2021-10-17 22:00:00                 2
# 2       2  61a3c339002f6ba194601eea  ... 2021-10-18 22:00:00                 3
# 3       3  61a3c339002f6ba194601ee9  ... 2021-10-18 22:00:00                 1
# 4       4  61a3c339002f6ba194601ee8  ... 2021-10-10 22:00:00                 2
# 5       0  61a3c36c002f6ba194601ef1  ... 2021-11-16 23:00:00                 3
# 6       1  61a3c36c002f6ba194601ef2  ... 2021-11-12 23:00:00                 5
# 7       2  61a3c36c002f6ba194601eef  ... 2021-11-11 23:00:00                 2
# 8       3  61a3c36c002f6ba194601ef0  ... 2021-11-16 23:00:00                 4
# 9       4  61a3c36c002f6ba194601ef3  ... 2021-11-18 23:00:00                 5
# 10      5  61a3c36c002f6ba194601eee  ... 2021-11-27 23:00:00                 5
#
# [11 rows x 5 columns]

# %%
df_multe_complessivo = df_multe.append(df_multe1, ignore_index=True)
df_multe_complessivo
# Out:
#                          _id    targa                data  codice_infrazione
# 0   61a3c339002f6ba194601ee7  BM665RE 2021-10-10 22:00:00                  1
# 1   61a3c339002f6ba194601eeb  DS456AS 2021-10-17 22:00:00                  2
# 2   61a3c339002f6ba194601eea  DS456AS 2021-10-18 22:00:00                  3
# 3   61a3c339002f6ba194601ee9  BM665RE 2021-10-18 22:00:00                  1
# 4   61a3c339002f6ba194601ee8  DS456AS 2021-10-10 22:00:00                  2
# 5   61a3c36c002f6ba194601ef1  DS456AS 2021-11-16 23:00:00                  3
# 6   61a3c36c002f6ba194601ef2  DS456AS 2021-11-12 23:00:00                  5
# 7   61a3c36c002f6ba194601eef  DS456AS 2021-11-11 23:00:00                  2
# 8   61a3c36c002f6ba194601ef0  BM665RE 2021-11-16 23:00:00                  4
# 9   61a3c36c002f6ba194601ef3  XX000YY 2021-11-18 23:00:00                  5
# 10  61a3c36c002f6ba194601eee  BM665RE 2021-11-27 23:00:00                  5

# %%
df_multe_complessivo = pd.concat([df_multe, df_multe1])
df_multe_complessivo
# Out:
#                         _id    targa                data  codice_infrazione
# 0  61a3c339002f6ba194601ee7  BM665RE 2021-10-10 22:00:00                  1
# 1  61a3c339002f6ba194601eeb  DS456AS 2021-10-17 22:00:00                  2
# 2  61a3c339002f6ba194601eea  DS456AS 2021-10-18 22:00:00                  3
# 3  61a3c339002f6ba194601ee9  BM665RE 2021-10-18 22:00:00                  1
# 4  61a3c339002f6ba194601ee8  DS456AS 2021-10-10 22:00:00                  2
# 0  61a3c36c002f6ba194601ef1  DS456AS 2021-11-16 23:00:00                  3
# 1  61a3c36c002f6ba194601ef2  DS456AS 2021-11-12 23:00:00                  5
# 2  61a3c36c002f6ba194601eef  DS456AS 2021-11-11 23:00:00                  2
# 3  61a3c36c002f6ba194601ef0  BM665RE 2021-11-16 23:00:00                  4
# 4  61a3c36c002f6ba194601ef3  XX000YY 2021-11-18 23:00:00                  5
# 5  61a3c36c002f6ba194601eee  BM665RE 2021-11-27 23:00:00                  5

# %% [markdown]
# Vediamo ora come unire le informazioni presenti in dataframe che hanno una struttura diversa tranne che per un campo (o più campi) che contengono informazioni che permettono di collegare un record (una riga) di un dataframe con uno o più record dell'altro dataframe:
#
# <img src="https://miro.medium.com/max/1838/1*ZCpo3gXuXI4KFhKivEt2ZA.png" width=800>
#
# Nell'esempio il campo "id" permette di mettere in relazione le righe del primo dataframe con le righe del secondo dataframe. Prestare attenzione al fatto che il legame non è causato tanto dal nome del campo (che è lo stesso per rendere più leggibile la relazione) quanto dal valore contenuto in quel campo. L'id 2 indica Jenny in un dataframe e una donna di 31 anni nel secondo dataframe: siccome l'id è lo stesso, vuol dire che Jenny ha 31 anni.
#
# Per fare questa operazione di join utilizzeremo il metodo di Pandas merge() che effettua una join (una associazione, una connessione, un collegamento) tra i record dei due dataframe dove il campo in comune contiene lo stesso valore.
#
# Ci sono diversi tipi di join, ognuna che effettua una associazione dal risultato diverso. Le join principali sono la left join, la right join, la outer join e la inner join.

# %% [markdown]
# <img src="https://i1.wp.com/datascienceparichay.com/wp-content/uploads/2021/01/Left-Join-diagram.png?w=800&ssl=1">

# %%
df_proprietari_multe = pd.merge(df_prop, df_multe_complessivo, how="left", on=["targa"])
df_proprietari_multe
# Out:
#                        _id_x     nome  ...                data codice_infrazione
# 0   61a3bf26002f6ba194601eba    carlo  ...                 NaT               NaN
# 1   61a3bf26002f6ba194601eb9    carlo  ... 2021-10-17 22:00:00               2.0
# 2   61a3bf26002f6ba194601eb9    carlo  ... 2021-10-18 22:00:00               3.0
# 3   61a3bf26002f6ba194601eb9    carlo  ... 2021-10-10 22:00:00               2.0
# 4   61a3bf26002f6ba194601eb9    carlo  ... 2021-11-16 23:00:00               3.0
# 5   61a3bf26002f6ba194601eb9    carlo  ... 2021-11-12 23:00:00               5.0
# 6   61a3bf26002f6ba194601eb9    carlo  ... 2021-11-11 23:00:00               2.0
# 7   61a3bf26002f6ba194601eb8    mario  ... 2021-10-10 22:00:00               1.0
# 8   61a3bf26002f6ba194601eb8    mario  ... 2021-10-18 22:00:00               1.0
# 9   61a3bf26002f6ba194601eb8    mario  ... 2021-11-16 23:00:00               4.0
# 10  61a3bf26002f6ba194601eb8    mario  ... 2021-11-27 23:00:00               5.0
# ...

# %% [markdown]
# <img src="https://i2.wp.com/datascienceparichay.com/wp-content/uploads/2021/01/Right-Join-diagram.png?w=800&ssl=1">

# %%
df_proprietari_multe = pd.merge(df_prop, df_multe_complessivo, how="right", on=["targa"])
df_proprietari_multe
# Out:
#                        _id_x   nome  ...                data codice_infrazione
# 0   61a3bf26002f6ba194601eb8  mario  ... 2021-10-10 22:00:00                 1
# 1   61a3bf26002f6ba194601eb9  carlo  ... 2021-10-17 22:00:00                 2
# 2   61a3bf26002f6ba194601eb9  carlo  ... 2021-10-18 22:00:00                 3
# 3   61a3bf26002f6ba194601eb8  mario  ... 2021-10-18 22:00:00                 1
# 4   61a3bf26002f6ba194601eb9  carlo  ... 2021-10-10 22:00:00                 2
# 5   61a3bf26002f6ba194601eb9  carlo  ... 2021-11-16 23:00:00                 3
# 6   61a3bf26002f6ba194601eb9  carlo  ... 2021-11-12 23:00:00                 5
# 7   61a3bf26002f6ba194601eb9  carlo  ... 2021-11-11 23:00:00                 2
# 8   61a3bf26002f6ba194601eb8  mario  ... 2021-11-16 23:00:00                 4
# 9                        NaN    NaN  ... 2021-11-18 23:00:00                 5
# 10  61a3bf26002f6ba194601eb8  mario  ... 2021-11-27 23:00:00                 5
#
# [11 rows x 7 columns]

# %% [markdown]
# <img src="https://i1.wp.com/datascienceparichay.com/wp-content/uploads/2021/01/Outer-Join-diagram.png?w=800&ssl=1" >

# %%
df_proprietari_multe = pd.merge(df_prop, df_multe_complessivo, how="outer", on=["targa"])
df_proprietari_multe
# Out:
#                        _id_x     nome  ...                data codice_infrazione
# 0   61a3bf26002f6ba194601eba    carlo  ...                 NaT               NaN
# 1   61a3bf26002f6ba194601eb9    carlo  ... 2021-10-17 22:00:00               2.0
# 2   61a3bf26002f6ba194601eb9    carlo  ... 2021-10-18 22:00:00               3.0
# 3   61a3bf26002f6ba194601eb9    carlo  ... 2021-10-10 22:00:00               2.0
# 4   61a3bf26002f6ba194601eb9    carlo  ... 2021-11-16 23:00:00               3.0
# 5   61a3bf26002f6ba194601eb9    carlo  ... 2021-11-12 23:00:00               5.0
# 6   61a3bf26002f6ba194601eb9    carlo  ... 2021-11-11 23:00:00               2.0
# 7   61a3bf26002f6ba194601eb8    mario  ... 2021-10-10 22:00:00               1.0
# 8   61a3bf26002f6ba194601eb8    mario  ... 2021-10-18 22:00:00               1.0
# 9   61a3bf26002f6ba194601eb8    mario  ... 2021-11-16 23:00:00               4.0
# 10  61a3bf26002f6ba194601eb8    mario  ... 2021-11-27 23:00:00               5.0
# ...

# %% [markdown]
# <img src="https://i0.wp.com/datascienceparichay.com/wp-content/uploads/2021/01/Inner-Join-diagram.png?w=800&ssl=1">

# %%
df_proprietari_multe = pd.merge(df_prop, df_multe_complessivo, how="inner", on=["targa"])
df_proprietari_multe
# Out:
#                       _id_x   nome  ...                data codice_infrazione
# 0  61a3bf26002f6ba194601eb9  carlo  ... 2021-10-17 22:00:00                 2
# 1  61a3bf26002f6ba194601eb9  carlo  ... 2021-10-18 22:00:00                 3
# 2  61a3bf26002f6ba194601eb9  carlo  ... 2021-10-10 22:00:00                 2
# 3  61a3bf26002f6ba194601eb9  carlo  ... 2021-11-16 23:00:00                 3
# 4  61a3bf26002f6ba194601eb9  carlo  ... 2021-11-12 23:00:00                 5
# 5  61a3bf26002f6ba194601eb9  carlo  ... 2021-11-11 23:00:00                 2
# 6  61a3bf26002f6ba194601eb8  mario  ... 2021-10-10 22:00:00                 1
# 7  61a3bf26002f6ba194601eb8  mario  ... 2021-10-18 22:00:00                 1
# 8  61a3bf26002f6ba194601eb8  mario  ... 2021-11-16 23:00:00                 4
# 9  61a3bf26002f6ba194601eb8  mario  ... 2021-11-27 23:00:00                 5
#
# [10 rows x 7 columns]

# %% [markdown]
# Esercizi
#
# 1. trovare i nominativi dei proprietari di auto che hanno commesso un'infrazione legata ai limiti di velocità (eccesso di velocità)
#
# 2. trovare il numero di infrazioni per ogni tipologia di effrazione. Visualizzare il nome dell'effrazione e il numero di multe
#
# 3. trovare i nominativi dei proprietari e il tipo di infrazione commessa in un giorno particolare inserito dall'utente
#
# 4. visualizzare le targhe delle auto con cui non è stata commessa nessuna infrazione
#
# 5. visualizzare le tipologie di infrazione per cui non è stata elevata nessuna multa

# %% [markdown]
# **NUMERO 1**

# %%
# trovare i nominativi dei proprietari di auto che hanno commesso un'infrazione legata ai limiti di velocità (eccesso di velocità)

df_proprietari_multe[df_proprietari_multe.codice_infrazione == 1][["nome", "cognome"]].drop_duplicates()
# Out:
#     nome cognome
# 6  mario   rossi

# %% [markdown]
# **modo come fatto in classe**

# %%
df_prop_mult = pd.merge(df_prop, df_multe_complessivo, how ="inner", on=["targa"])
df_prop_mult
# Out:
#                       _id_x   nome  ...                data codice_infrazione
# 0  61a3bf26002f6ba194601eb9  carlo  ... 2021-10-17 22:00:00                 2
# 1  61a3bf26002f6ba194601eb9  carlo  ... 2021-10-18 22:00:00                 3
# 2  61a3bf26002f6ba194601eb9  carlo  ... 2021-10-10 22:00:00                 2
# 3  61a3bf26002f6ba194601eb9  carlo  ... 2021-11-16 23:00:00                 3
# 4  61a3bf26002f6ba194601eb9  carlo  ... 2021-11-12 23:00:00                 5
# 5  61a3bf26002f6ba194601eb9  carlo  ... 2021-11-11 23:00:00                 2
# 6  61a3bf26002f6ba194601eb8  mario  ... 2021-10-10 22:00:00                 1
# 7  61a3bf26002f6ba194601eb8  mario  ... 2021-10-18 22:00:00                 1
# 8  61a3bf26002f6ba194601eb8  mario  ... 2021-11-16 23:00:00                 4
# 9  61a3bf26002f6ba194601eb8  mario  ... 2021-11-27 23:00:00                 5
#
# [10 rows x 7 columns]

# %%
df_prop_mult.codice_infrazione.dtypes
# Out:
# dtype('int64')

# %%
df_tipo_infraz.codice.dtypes
# Out:
# dtype('O')

# %%
#  per convertire
df_tipo_infraz["codice"] = df_tipo_infraz["codice"].astype(int)

# %%
df_tipo_infraz.codice.dtypes
# Out:
# dtype('int64')

# %% [markdown]
# **da errore perché i merge funzionano solo con gli stessi tipi di valori**

# %%
#  si usa left_on = "codice_infrazione", right_on = "codice" quando vuoi unire 2 df ma il nome della colonna su cui basare l'unione è diverso
df_prop_mult_infra = pd.merge(df_prop_mult, df_tipo_infraz, how = "inner", left_on = "codice_infrazione", right_on = "codice")
df_prop_mult_infra

# %%
df_prop_mult_infra = pd.merge(df_prop_mult, df_tipo_infraz, how = "inner", left_on = "codice_infrazione", right_on = "codice")
df_prop_mult_infra
# Out:
#                       _id_x  ...                                               note
# 0  61a3bf26002f6ba194601eb9  ...                   tra 10 e 40 km/h oltre il limite
# 1  61a3bf26002f6ba194601eb9  ...                   tra 10 e 40 km/h oltre il limite
# 2  61a3bf26002f6ba194601eb9  ...                   tra 10 e 40 km/h oltre il limite
# 3  61a3bf26002f6ba194601eb9  ...  sospensione patente da 1 a 3 mesi se recidiva ...
# 4  61a3bf26002f6ba194601eb9  ...  sospensione patente da 1 a 3 mesi se recidiva ...
# 5  61a3bf26002f6ba194601eb9  ...                    eventuale arresto da 1 a 8 mesi
# 6  61a3bf26002f6ba194601eb8  ...                    eventuale arresto da 1 a 8 mesi
# 7  61a3bf26002f6ba194601eb8  ...                     fino a 10 km/h oltre il limite
# 8  61a3bf26002f6ba194601eb8  ...                     fino a 10 km/h oltre il limite
# 9  61a3bf26002f6ba194601eb8  ...                  sospensione patente da 2 a 6 mesi
#
# [10 rows x 13 columns]

# %%
# trovare i nominativi dei proprietari di auto che hanno commesso un'infrazione legata ai limiti di velocità (eccesso di velocità)
df_prop_mult_infra[df_prop_mult_infra["nome_y"] == "eccesso di velocità"]
# Out:
#                       _id_x  ...                              note
# 0  61a3bf26002f6ba194601eb9  ...  tra 10 e 40 km/h oltre il limite
# 1  61a3bf26002f6ba194601eb9  ...  tra 10 e 40 km/h oltre il limite
# 2  61a3bf26002f6ba194601eb9  ...  tra 10 e 40 km/h oltre il limite
# 7  61a3bf26002f6ba194601eb8  ...    fino a 10 km/h oltre il limite
# 8  61a3bf26002f6ba194601eb8  ...    fino a 10 km/h oltre il limite
#
# [5 rows x 13 columns]

# %%
df_prop_mult_infra[df_prop_mult_infra["nome_y"] == "eccesso di velocità"].groupby(["nome_x", "cognome"]).sum()["importo massimo"].reset_index()
# Out:
#   nome_x cognome  importo massimo
# 0  carlo   verdi           2037.0
# 1  mario   rossi            338.0

# %% [markdown]
# **NUMERO 2**

# %%
# trovare il numero di infrazioni per ogni tipologia di effrazione. Visualizzare il nome dell'effrazione e il numero di multe

# %%
df_prop_mult_infra
# Out:
#                       _id_x  ...                                               note
# 0  61a3bf26002f6ba194601eb9  ...                   tra 10 e 40 km/h oltre il limite
# 1  61a3bf26002f6ba194601eb9  ...                   tra 10 e 40 km/h oltre il limite
# 2  61a3bf26002f6ba194601eb9  ...                   tra 10 e 40 km/h oltre il limite
# 3  61a3bf26002f6ba194601eb9  ...  sospensione patente da 1 a 3 mesi se recidiva ...
# 4  61a3bf26002f6ba194601eb9  ...  sospensione patente da 1 a 3 mesi se recidiva ...
# 5  61a3bf26002f6ba194601eb9  ...                    eventuale arresto da 1 a 8 mesi
# 6  61a3bf26002f6ba194601eb8  ...                    eventuale arresto da 1 a 8 mesi
# 7  61a3bf26002f6ba194601eb8  ...                     fino a 10 km/h oltre il limite
# 8  61a3bf26002f6ba194601eb8  ...                     fino a 10 km/h oltre il limite
# 9  61a3bf26002f6ba194601eb8  ...                  sospensione patente da 2 a 6 mesi
#
# [10 rows x 13 columns]

# %%
df_prop_mult_infra.groupby("nome_y").count()["cognome"]
# Out:
# nome_y
# circolazione corsia di emergenza    1
# eccesso di velocità                 5
# gare di velocità non autorizzate    2
# semaforo rosso                      2
# Name: cognome, dtype: int64

# %% [markdown]
# **NUMERO 3**

# %%
#trovare i nominativi dei proprietari e il tipo di infrazione commessa in un giorno particolare inserito dall'utente
df_multe.data.dtypes
# Out:
# dtype('<M8[ns]')

# %%
df_multe["data"] = df_multe["data"].astype(str)

# %%
df_multe.data.dtypes
# Out:
# dtype('O')

# %%
data_inserita = input("inserire data e ore: ")
# Out:
# inserire data e ore: 2021-10-17 22:00:00

# %%
df_prop_multe = pd.merge(df_prop, df_multe, how = "inner", on="targa")
df_prop_multe_infraz = pd.merge(df_prop_multe, df_tipo_infraz, how = "inner", left_on="codice_infrazione", right_on="codice")
df_prop_multe_infraz
# Out:
#                       _id_x  ...                                               note
# 0  61a3bf26002f6ba194601eb9  ...                   tra 10 e 40 km/h oltre il limite
# 1  61a3bf26002f6ba194601eb9  ...                   tra 10 e 40 km/h oltre il limite
# 2  61a3bf26002f6ba194601eb9  ...  sospensione patente da 1 a 3 mesi se recidiva ...
# 3  61a3bf26002f6ba194601eb8  ...                     fino a 10 km/h oltre il limite
# 4  61a3bf26002f6ba194601eb8  ...                     fino a 10 km/h oltre il limite
#
# [5 rows x 13 columns]

# %%
df_prop_multe_infraz[df_prop_multe_infraz.data == data_inserita][["nome_x", "cognome", "nome_y"]]
# Out:
#   nome_x cognome               nome_y
# 0  carlo   verdi  eccesso di velocità

# %% [markdown]
# **NUMERO 4**

# %%
# visualizzare le targhe delle auto con cui non è stata commessa nessuna infrazione

# %%
df_prop
# Out:
#                         _id     nome  cognome    targa
# 0  61a3bf26002f6ba194601eba    carlo    verdi  DD876CA
# 1  61a3bf26002f6ba194601eb9    carlo    verdi  DS456AS
# 2  61a3bf26002f6ba194601eb8    mario    rossi  BM665RE
# 3  61a3bf26002f6ba194601ebb  stefano  bianchi  AS765ZA

# %%
df_multe_complessivo
# Out:
#                         _id    targa                data  codice_infrazione
# 0  61a3c339002f6ba194601ee7  BM665RE 2021-10-10 22:00:00                  1
# 1  61a3c339002f6ba194601eeb  DS456AS 2021-10-17 22:00:00                  2
# 2  61a3c339002f6ba194601eea  DS456AS 2021-10-18 22:00:00                  3
# 3  61a3c339002f6ba194601ee9  BM665RE 2021-10-18 22:00:00                  1
# 4  61a3c339002f6ba194601ee8  DS456AS 2021-10-10 22:00:00                  2
# 0  61a3c36c002f6ba194601ef1  DS456AS 2021-11-16 23:00:00                  3
# 1  61a3c36c002f6ba194601ef2  DS456AS 2021-11-12 23:00:00                  5
# 2  61a3c36c002f6ba194601eef  DS456AS 2021-11-11 23:00:00                  2
# 3  61a3c36c002f6ba194601ef0  BM665RE 2021-11-16 23:00:00                  4
# 4  61a3c36c002f6ba194601ef3  XX000YY 2021-11-18 23:00:00                  5
# 5  61a3c36c002f6ba194601eee  BM665RE 2021-11-27 23:00:00                  5

# %%
df_proprietari_multe = pd.merge(df_prop, df_multe_complessivo, how="outer", on=["targa"])
df_proprietari_multe
# Out:
#                        _id_x     nome  ...                data codice_infrazione
# 0   61a3bf26002f6ba194601eba    carlo  ...                 NaT               NaN
# 1   61a3bf26002f6ba194601eb9    carlo  ... 2021-10-17 22:00:00               2.0
# 2   61a3bf26002f6ba194601eb9    carlo  ... 2021-10-18 22:00:00               3.0
# 3   61a3bf26002f6ba194601eb9    carlo  ... 2021-10-10 22:00:00               2.0
# 4   61a3bf26002f6ba194601eb9    carlo  ... 2021-11-16 23:00:00               3.0
# 5   61a3bf26002f6ba194601eb9    carlo  ... 2021-11-12 23:00:00               5.0
# 6   61a3bf26002f6ba194601eb9    carlo  ... 2021-11-11 23:00:00               2.0
# 7   61a3bf26002f6ba194601eb8    mario  ... 2021-10-10 22:00:00               1.0
# 8   61a3bf26002f6ba194601eb8    mario  ... 2021-10-18 22:00:00               1.0
# 9   61a3bf26002f6ba194601eb8    mario  ... 2021-11-16 23:00:00               4.0
# 10  61a3bf26002f6ba194601eb8    mario  ... 2021-11-27 23:00:00               5.0
# ...

# %%
df_proprietari_multe[df_proprietari_multe.codice_infrazione.isnull()]["targa"]
# Out:
# 0     DD876CA
# 11    AS765ZA
# Name: targa, dtype: object

# %% [markdown]
# **NUMERO 5**

# %%
# visualizzare le tipologie di infrazione per cui non è stata elevata nessuna multa

# %%
df_multe_complessivo
# Out:
#                         _id    targa                data  codice_infrazione
# 0  61a3c339002f6ba194601ee7  BM665RE 2021-10-10 22:00:00                  1
# 1  61a3c339002f6ba194601eeb  DS456AS 2021-10-17 22:00:00                  2
# 2  61a3c339002f6ba194601eea  DS456AS 2021-10-18 22:00:00                  3
# 3  61a3c339002f6ba194601ee9  BM665RE 2021-10-18 22:00:00                  1
# 4  61a3c339002f6ba194601ee8  DS456AS 2021-10-10 22:00:00                  2
# 0  61a3c36c002f6ba194601ef1  DS456AS 2021-11-16 23:00:00                  3
# 1  61a3c36c002f6ba194601ef2  DS456AS 2021-11-12 23:00:00                  5
# 2  61a3c36c002f6ba194601eef  DS456AS 2021-11-11 23:00:00                  2
# 3  61a3c36c002f6ba194601ef0  BM665RE 2021-11-16 23:00:00                  4
# 4  61a3c36c002f6ba194601ef3  XX000YY 2021-11-18 23:00:00                  5
# 5  61a3c36c002f6ba194601eee  BM665RE 2021-11-27 23:00:00                  5

# %%
df

# %%
df_tipo_infraz
# Out:
#                         _id  ...                                               note
# 0  61a49d205a4cb744e63c8d38  ...                  sospensione patente da 2 a 6 mesi
# 1  61a49d205a4cb744e63c8d36  ...                   tra 10 e 40 km/h oltre il limite
# 2  61a49d205a4cb744e63c8d35  ...                     fino a 10 km/h oltre il limite
# 3  61a49d205a4cb744e63c8d39  ...                    eventuale arresto da 1 a 8 mesi
# 4  61a49d205a4cb744e63c8d37  ...  sospensione patente da 1 a 3 mesi se recidiva ...
# 5  61a49d205a4cb744e63c8d3a  ...           eventuale arresto da sei mesi ad un anno
#
# [6 rows x 6 columns]

# %%
df_tipo_infraz_multe_complessivo = pd.merge(df_multe_complessivo, df_tipo_infraz, how = "outer", left_on="codice_infrazione", right_on="codice")
df_tipo_infraz_multe_complessivo
# Out:
#                        _id_x  ...                                               note
# 0   61a3c339002f6ba194601ee7  ...                     fino a 10 km/h oltre il limite
# 1   61a3c339002f6ba194601ee9  ...                     fino a 10 km/h oltre il limite
# 2   61a3c339002f6ba194601eeb  ...                   tra 10 e 40 km/h oltre il limite
# 3   61a3c339002f6ba194601ee8  ...                   tra 10 e 40 km/h oltre il limite
# 4   61a3c36c002f6ba194601eef  ...                   tra 10 e 40 km/h oltre il limite
# 5   61a3c339002f6ba194601eea  ...  sospensione patente da 1 a 3 mesi se recidiva ...
# 6   61a3c36c002f6ba194601ef1  ...  sospensione patente da 1 a 3 mesi se recidiva ...
# 7   61a3c36c002f6ba194601ef2  ...                    eventuale arresto da 1 a 8 mesi
# 8   61a3c36c002f6ba194601ef3  ...                    eventuale arresto da 1 a 8 mesi
# 9   61a3c36c002f6ba194601eee  ...                    eventuale arresto da 1 a 8 mesi
# ...

# %%
df_tipo_infraz_multe_complessivo[df_tipo_infraz_multe_complessivo.targa.isnull()][["codice", "note"]]
# Out:
#     codice                                      note
# 11       6  eventuale arresto da sei mesi ad un anno
